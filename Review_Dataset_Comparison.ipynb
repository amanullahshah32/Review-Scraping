# %% [markdown]
# <a href="https://colab.research.google.com/github/amanullahshah32/Review-Scraping/blob/main/Review_Dataset_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url1 = 'https://raw.githubusercontent.com/amanullahshah32/Review-Scraping/refs/heads/main/Dataset/all_app_reviews.csv'
all_dataset = pd.read_csv(url1)

# %%
url2 = 'https://raw.githubusercontent.com/amanullahshah32/Review-Scraping/refs/heads/main/Dataset/cleaned_dataset.csv'
cleaned_dataset = pd.read_csv(url2)

# %%
all_dataset[all_dataset['review_description'].str.split().str.len() > 4]
# Out:
#             source                             review_id      user_name  \
# 9      Google Play  f18a5ffe-872c-4f63-bf38-2c0eb5a52170  A Google user
# 23     Google Play  7343b2f4-d63a-40f8-831a-6d981790e460  A Google user
# 42     Google Play  43735aea-6ed6-46d6-b40d-a05a6aa85a4f  A Google user
# 43     Google Play  09539ed2-15f0-4ea3-87b9-3cee2ac2f561  A Google user
# 47     Google Play  2c45e801-7b20-4265-83d3-4c630695fb65  A Google user
# ...            ...                                   ...            ...
# 99382  Google Play  451b0abd-2872-4a1f-9c80-f90d26994b54  A Google user
# 99384  Google Play  89112cd6-2d2b-4f2e-abc5-8e2479f62773  A Google user
# 99385  Google Play  6b7e1669-b16c-498c-bae9-9f3579165826  A Google user
# 99391  Google Play  faaf5dc6-e694-413e-8074-f85b9bab8b25  A Google user
# 99393  Google Play  1f45b543-31fa-46ba-b312-117e3e55b704  A Google user
#
#        review_title                                 review_description  \
# ...

# %%
cleaned_dataset[cleaned_dataset['review_description'].str.split().str.len() > 4]
# Out:
#             source                             review_id       user_name  \
# 0      Google Play  f18a5ffe-872c-4f63-bf38-2c0eb5a52170   A Google user
# 5      Google Play  7343b2f4-d63a-40f8-831a-6d981790e460   A Google user
# 9      Google Play  43735aea-6ed6-46d6-b40d-a05a6aa85a4f   A Google user
# 10     Google Play  09539ed2-15f0-4ea3-87b9-3cee2ac2f561   A Google user
# 12     Google Play  2c45e801-7b20-4265-83d3-4c630695fb65   A Google user
# ...            ...                                   ...             ...
# 65260  Google Play  2a16857b-4eaa-4d86-a288-09e496f0bcd9  ashraful Haque
# 65261  Google Play  115f0fa0-7aa2-4626-ba61-e96dc63d6c77      Md Mijanur
# 65265  Google Play  8089cb4d-3355-41f1-985a-085092334815   A Google user
# 65268  Google Play  e4b4ed3f-2629-4151-89bb-3cc410200d3d   A Google user
# 65269  Google Play  6b7e1669-b16c-498c-bae9-9f3579165826   A Google user
#
#        review_title                                 review_description  \
# ...
