# %% [markdown]
# <a href="https://colab.research.google.com/github/amanullahshah32/Review-Scraping/blob/main/Attempt_1_using_google_play_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Install Libraries**

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.6 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# !pip install app_store_scraper
# Out:
# Collecting app_store_scraper
#   Downloading app_store_scraper-0.3.5-py3-none-any.whl.metadata (5.1 kB)
# Collecting requests==2.23.0 (from app_store_scraper)
#   Downloading requests-2.23.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting chardet<4,>=3.0.2 (from requests==2.23.0->app_store_scraper)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna<3,>=2.5 (from requests==2.23.0->app_store_scraper)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests==2.23.0->app_store_scraper)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.23.0->app_store_scraper) (2024.8.30)
# Downloading app_store_scraper-0.3.5-py3-none-any.whl (8.3 kB)
# Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.2 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 4.9 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.1 MB/s eta 0:00:00
# Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: chardet, urllib3, idna, requests, app_store_scraper
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.17.0 requires requests>=2.27.1, but you have requests 2.23.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.23.0 which is incompatible.
# tweepy 4.14.0 requires requests<3,>=2.27.0, but you have requests 2.23.0 which is incompatible.
# yfinance 0.2.43 requires requests>=2.31, but you have requests 2.23.0 which is incompatible.
# Successfully installed app_store_scraper-0.3.5 chardet-3.0.4 idna-2.10 requests-2.23.0 urllib3-1.25.11

# %% [markdown]
# ## **Import Dependencies**

# %%
from google_play_scraper import app, Sort, reviews_all
from app_store_scraper import AppStore
import pandas as pd
import numpy as np
import json, os, uuid

# %% [markdown]
# ## **Google Play Store reviews**

# %%
g_reviews = reviews_all(
    'com.twgbd.dims',
    sleep_milliseconds=0, # default to 0
    lang = 'en', # default to usa
    sort = Sort.NEWEST, # defaults to sort.most_relevent
)

# %%
g_df = pd.DataFrame(np.array(g_reviews),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'

g_df2
# Out:
#             source                             review_id      user_name  \
# 0      Google Play  e90bdc72-5ba9-4f84-823e-687cb00344ef  A Google user
# 1      Google Play  8ec65be1-5a24-4a96-98af-5cae144f4c25  A Google user
# 2      Google Play  1239635a-5f4c-4c68-817a-2e81ee2c5dfa  A Google user
# 3      Google Play  a7c0f6a1-7660-4a53-b2b3-909c11cf4164  A Google user
# 4      Google Play  2be07e85-392b-49ce-847d-28c1f3ed4173  A Google user
# ...            ...                                   ...            ...
# 16058  Google Play  f1a2d585-d39b-4fcf-a407-e96fc8277c44  A Google user
# 16059  Google Play  68e1506e-bc21-48e3-be2f-8b74754ade15  A Google user
# 16060  Google Play  df0730bb-f766-4b33-9c1e-78d9e6240b96  A Google user
# 16061  Google Play  74888924-b6d5-40e1-ad2f-0e524c11581a  A Google user
# 16062  Google Play  ec918f60-1add-4069-8dd8-894fbe063aed  A Google user
#
#       review_title                                 review_description  rating  \
# 0             None                                           good app       5
# 1             None                                               good       1
# 2             None                                          good apps       5
# 3             None                                   very good apps..       5
# 4             None                                               nice       5
# ...            ...                                                ...     ...
# 16058         None                        Need it badly on the move!!       4
# 16059         None            Very helping.......but need improvement       5
# 16060         None  keep updating the drug names regularly to make...       5
# 16061         None                                          Excellent       5
# 16062         None             must have app for any smartphone user.       5
#
#        thumbs_up         review_date  \
# 0              0 2024-09-21 08:03:14
# 1              0 2024-09-21 07:58:28
# 2              0 2024-09-21 07:45:06
# 3              0 2024-09-21 06:35:45
# 4              0 2024-09-21 06:31:05
# ...          ...                 ...
# 16058          0 2014-11-25 06:40:31
# 16059          0 2014-11-25 06:25:45
# 16060          4 2014-11-25 05:32:44
# 16061          0 2014-11-24 17:25:27
# 16062          3 2014-11-24 13:42:16
#
#                                       developer_response  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 16058                                             thanks
# 16059  What kind of improvement do you expect? Please...
# 16060                                               None
# 16061                                               None
# 16062                                               None
#
#       developer_response_date appVersion laguage_code country_code
# 0                         NaT      2.1.7           en           us
# 1                         NaT      2.1.7           en           us
# 2                         NaT      2.1.7           en           us
# 3                         NaT      2.1.7           en           us
# 4                         NaT      2.1.7           en           us
# ...                       ...        ...          ...          ...
# 16058     2014-11-25 06:44:03       None           en           us
# 16059     2014-11-25 06:45:11       None           en           us
# 16060                     NaT        1.2           en           us
# 16061                     NaT       None           en           us
# 16062                     NaT       None           en           us
#
# [16063 rows x 13 columns]

# %% [markdown]
# ## **App Store reviews**

# %%
## App store reviews
a_reviews = AppStore('us', 'dims-itmedicus', '944794906')
a_reviews.review()

# %%
a_df = pd.DataFrame(np.array(a_reviews.reviews),columns=['review'])
a_df2 = a_df.join(pd.DataFrame(a_df.pop('review').tolist()))

a_df2.drop(columns={'isEdited'},inplace = True)
a_df2.insert(loc=0, column='source', value='App Store')
a_df2['developer_response_date'] = None
a_df2['thumbs_up'] = None
a_df2['laguage_code'] = 'en'
a_df2['country_code'] = 'us'
a_df2.insert(loc=1, column='review_id', value=[uuid.uuid4() for _ in range(len(a_df2.index))])
a_df2.rename(columns= {'review': 'review_description','userName': 'user_name', 'date': 'review_date','title': 'review_title', 'developerResponse': 'developer_response'},inplace = True)
a_df2 = a_df2.where(pd.notnull(a_df2), None)

# %% [markdown]
# ## **Merged Reviews**

# %%
result = pd.concat([g_df2,a_df2])
result
# Out:
# <ipython-input-8-579ef8df6a00>:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result = pd.concat([g_df2,a_df2])
#           source                             review_id           user_name  \
# 0    Google Play  e90bdc72-5ba9-4f84-823e-687cb00344ef       A Google user
# 1    Google Play  8ec65be1-5a24-4a96-98af-5cae144f4c25       A Google user
# 2    Google Play  1239635a-5f4c-4c68-817a-2e81ee2c5dfa       A Google user
# 3    Google Play  a7c0f6a1-7660-4a53-b2b3-909c11cf4164       A Google user
# 4    Google Play  2be07e85-392b-49ce-847d-28c1f3ed4173       A Google user
# ..           ...                                   ...                 ...
# 224    App Store  85ff4d2f-7ce1-40ca-ab24-3d0e20c21439        Nasir Shairy
# 225    App Store  ac31dfe9-eeb6-4acd-ac12-2cacce185108             Drsamim
# 226    App Store  df3dcd8d-a745-4049-9637-406068b64fe2  Dr. Rashedul Hasan
# 227    App Store  3eb165e7-7dc3-43e1-8d91-cbd2c293817c           Hasanul37
# 228    App Store  25a443cb-672a-452d-825b-f09cb2d354a1         doctor azad
#
#                            review_title  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ..                                  ...
# 224                     Excellent.  app
# 225                                  Dr
# 226                           Thanks...
# 227  Why no support for older iPhones ?
# 228                             Doctor.
#
#                                     review_description  rating thumbs_up  \
# 0                                             good app       5         0
# 1                                                 good       1         0
# 2                                            good apps       5         0
# 3                                     very good apps..       5         0
# 4                                                 nice       5         0
# ..                                                 ...     ...       ...
# 224                                           good job       5      None
# 225                                      Great app!!!!       5      None
# 226  Great work... Thanks.but more bugs to be fixed...       4      None
# 227  No iPhone 5 support for a mere 22 MB update? W...       2      None
# 228  thank u very much for this app.Pls improve or ...       5      None
#
#             review_date developer_response developer_response_date appVersion  \
# 0   2024-09-21 08:03:14               None                     NaT      2.1.7
# 1   2024-09-21 07:58:28               None                     NaT      2.1.7
# 2   2024-09-21 07:45:06               None                     NaT      2.1.7
# 3   2024-09-21 06:35:45               None                     NaT      2.1.7
# 4   2024-09-21 06:31:05               None                     NaT      2.1.7
# ..                  ...                ...                     ...        ...
# 224 2015-07-25 09:43:38               None                     NaT        NaN
# 225 2015-06-27 22:51:03               None                     NaT        NaN
# 226 2015-06-02 12:55:12               None                     NaT        NaN
# 227 2016-11-11 08:40:02               None                     NaT        NaN
# 228 2015-03-22 15:14:27               None                     NaT        NaN
#
#     laguage_code country_code
# 0             en           us
# 1             en           us
# 2             en           us
# 3             en           us
# 4             en           us
# ..           ...          ...
# 224           en           us
# 225           en           us
# 226           en           us
# 227           en           us
# 228           en           us
#
# [16292 rows x 13 columns]

# %%
g_reviews2 = reviews_all(
    'org.iggymedia.periodtracker',
    sleep_milliseconds=0, # default to 0
    lang = 'en', # default to usa
    sort = Sort.NEWEST, # defaults to sort.most_relevent
)

# %%
g_df = pd.DataFrame(np.array(g_reviews2),columns=['review'])
g_df2 = g_df.join(pd.DataFrame(g_df.pop('review').tolist()))

g_df2.drop(columns={'userImage', 'reviewCreatedVersion'},inplace = True)
g_df2.rename(columns= {'score': 'rating','userName': 'user_name', 'reviewId': 'review_id', 'content': 'review_description', 'at': 'review_date', 'replyContent': 'developer_response', 'repliedAt': 'developer_response_date', 'thumbsUpCount': 'thumbs_up'},inplace = True)
g_df2.insert(loc=0, column='source', value='Google Play')
g_df2.insert(loc=3, column='review_title', value=None)
g_df2['laguage_code'] = 'en'
g_df2['country_code'] = 'us'

g_df2
# Out:
#              source                             review_id      user_name  \
# 0       Google Play  84928fb7-852a-4f5a-b433-3b1ee119d4f1  A Google user
# 1       Google Play  931804bd-062f-4023-95bc-a58de82eb93f  A Google user
# 2       Google Play  a98cb8ea-277a-4c8c-828a-23b989d6de12  A Google user
# 3       Google Play  ba4aadae-ccbd-4934-9d90-506efce2855b  A Google user
# 4       Google Play  9df7fca6-f054-4164-b32f-0609e9ec85d6  A Google user
# ...             ...                                   ...            ...
# 187314  Google Play  4cca1dbf-1bfa-48c1-ba07-1bc8e2084ad7  A Google user
# 187315  Google Play  f1c7d8f2-cb30-4d69-9fd2-095c12980a90  A Google user
# 187316  Google Play  91fc0e94-d058-40c5-9895-9c6f1e724f13  A Google user
# 187317  Google Play  c0775901-2cfb-4ba2-90b4-ee99f1ff348d  A Google user
# 187318  Google Play  d193ec5f-9c48-4b01-b997-3d931333e045  A Google user
#
#        review_title                                 review_description  \
# 0              None                                          nice ap 🙂
# 1              None  Have been using flo for over 10years and it ha...
# 2              None                                               Good
# 3              None           Nice app I am using this app from 2019 .
# 4              None  its a very Very very Very very very very very ...
# ...             ...                                                ...
# 187314         None                                         Love this!
# 187315         None                                           Love it!
# 187316         None                      Awesome!! It works perfectly.
# 187317         None                                           Good app
# 187318         None                  Really nice to keep track of this
#
#         rating  thumbs_up         review_date developer_response  \
# 0            5          0 2024-09-21 08:32:34               None
# 1            5          0 2024-09-21 08:15:52               None
# 2            5          0 2024-09-21 08:08:19               None
# 3            5          0 2024-09-21 07:52:43               None
# 4            5          0 2024-09-21 06:58:12               None
# ...        ...        ...                 ...                ...
# 187314       5          1 2016-04-14 18:08:19               None
# 187315       5          8 2016-04-14 16:33:11               None
# 187316       5          7 2016-04-14 16:26:41               None
# 187317       5          7 2016-04-14 06:55:43               None
# 187318       5         10 2016-04-14 03:53:54               None
#
#        developer_response_date appVersion laguage_code country_code
# 0                          NaT     9.37.0           en           us
# 1                          NaT     9.61.2           en           us
# 2                          NaT     9.61.2           en           us
# 3                          NaT     9.59.1           en           us
# 4                          NaT     9.61.1           en           us
# ...                        ...        ...          ...          ...
# 187314                     NaT        1.0           en           us
# 187315                     NaT        1.0           en           us
# 187316                     NaT        1.0           en           us
# 187317                     NaT        1.0           en           us
# 187318                     NaT       None           en           us
#
# [187319 rows x 13 columns]
